# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
import openpyxl
print(openpyxl.__version__)
# Out:
# 3.1.5

# %%
import pandas as pd

df = pd.read_excel(
    "data/raw/gtd/globalterrorismdb_0522dist.xlsx",
    engine="openpyxl",
    nrows=5
)

print(df.head())
# Out:
#         eventid  iyear  imonth  iday  approxdate  extended  resolution  \
# 0  197000000001   1970       7     2         NaN         0         NaN
# 1  197000000002   1970       0     0         NaN         0         NaN
# 2  197001000001   1970       1     0         NaN         0         NaN
# 3  197001000002   1970       1     0         NaN         0         NaN
# 4  197001000003   1970       1     0         NaN         0         NaN
#
#    country         country_txt  region  ... addnotes scite1 scite2  scite3  \
# 0       58  Dominican Republic       2  ...      NaN    NaN    NaN     NaN
# 1      130              Mexico       1  ...      NaN    NaN    NaN     NaN
# 2      160         Philippines       5  ...      NaN    NaN    NaN     NaN
# 3       78              Greece       8  ...      NaN    NaN    NaN     NaN
# 4      101               Japan       4  ...      NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Columns: 135 entries, eventid to related
# dtypes: float64(89), int64(30), str(16)
# memory usage: 6.3 KB

# %%
import pandas as pd

print("Loading GTD dataset...")

df = pd.read_excel(
    "data/raw/gtd/globalterrorismdb_0522dist.xlsx",
    engine="openpyxl"
)

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Loading GTD dataset...
# Dataset loaded successfully!
# Shape: (209706, 135)

# %%
df.to_csv(
    "data/raw/gtd/globalterrorismdb_0522dist.csv",
    index=False
)

print("CSV created successfully!")
# Out:
# CSV created successfully!

# %%
import os

print(os.path.exists("data/raw/gtd/globalterrorismdb_0522dist.csv"))
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv(
    "data/raw/gtd/globalterrorismdb_0522dist.csv",
    encoding="latin1",
    low_memory=False
)

print(df.shape)
# Out:
# (209706, 135)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 209706 entries, 0 to 209705
# Columns: 135 entries, eventid to related
# dtypes: float64(54), int64(23), str(58)
# memory usage: 357.1 MB

# %%
df.columns.tolist()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
df.sample(5)
# Out:
#              eventid  iyear  imonth  iday   approxdate  extended resolution  \
# 157841  201601110057   2016       1    11          NaN         0        NaN
# 146273  201503290012   2015       3    29          NaN         0        NaN
# 95001   201001180012   2010       1    18          NaN         0        NaN
# 149620  201506160037   2015       6    16          NaN         0        NaN
# 186252  201805050010   2018       5     5  May 5, 2018         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 157841       95         Iraq      10  ...      NaN
# 146273        4  Afghanistan       6  ...      NaN
# 95001       153     Pakistan       6  ...      NaN
# 149620       34      Burundi      11  ...      NaN
# 186252       95         Iraq      10  ...      NaN
#
#                                                    scite1  \
# 157841  "Reprisals reported in Iraq after bombs," BBC,...
# 146273  "Roundup: Afghan conflicts claim 18 lives in 2...
# ...

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# gsubname3           209683
# weapsubtype4        209636
# weapsubtype4_txt    209636
# weaptype4           209633
# weaptype4_txt       209633
# claimmode3          209566
# claimmode3_txt      209566
# gsubname2           209522
# divert              209368
# claim3              209297
# guncertain3         209296
# gname3              209292
# ransomnote          209133
# attacktype3         209048
# attacktype3_txt     209048
# ransompaidus        208981
# claimmode2          208974
# claimmode2_txt      208974
# ransomamtus         208972
# ransompaid          208755
# dtype: int64

# %%
india_df = df[df["country_txt"] == "India"].copy()

print(india_df.shape)
# Out:
# (13929, 135)

# %%
india_df.to_csv(
    "data/processed/india_gtd.csv",
    index=False
)

print("India dataset saved!")
# Out:
# India dataset saved!
